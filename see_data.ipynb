# %%
import pandas as pd


df = pd.read_feather("race_stats_sca_truncated.feather")
df
# Out:
#      Race Number  Passes P1  Passes P2  Collisions  Choices  \
# 0              1          0          1           0       30
# 1              2          0          1           0       30
# 2              3          0          1           0       30
# 3              4          0          1           0       30
# 4              5          0          1           0       30
# ..           ...        ...        ...         ...      ...
# 495          496          0          1           0       30
# 496          497          0          0           0       30
# 497          498          0          0           0       30
# 498          499          0          0           0       30
# 499          500          0          0           0       30
#
#      Proportion Ahead P1  Proportion Ahead P2  Win P1  Win P2  Progress P1  \
# 0                   0.27                 0.73   False    True            3
# 1                   0.43                 0.57   False    True            3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Race Number            500 non-null    int64
#  1   Passes P1              500 non-null    int64
#  2   Passes P2              500 non-null    int64
#  3   Collisions             500 non-null    int64
#  4   Choices                500 non-null    int64
#  5   Proportion Ahead P1    500 non-null    float64
#  6   Proportion Ahead P2    500 non-null    float64
#  7   Win P1                 500 non-null    bool
#  8   Win P2                 500 non-null    bool
#  9   Progress P1            500 non-null    int64
#  10  Progress P2            500 non-null    int64
#  11  Out of Bounds P1       500 non-null    int64
#  12  Out of Bounds P2       500 non-null    int64
#  13  Progress Cost P1       500 non-null    float64
# ...

# %%
df = pd.read_feather("cost_stats_sca_truncated.feather")
df
# Out:
#        Theta_a1  Theta_b1  Theta_c1  Theta_a2  Theta_b2  Theta_c2  action1  \
# 0             1         1         1     0.001       0.0       0.0        7
# 1             1         1         1     0.001       0.0       0.0        8
# 2             1         1         1     0.001       0.0       0.0        4
# 3             1         1         1     0.001       0.0       0.0        4
# 4             1         1         1     0.001       0.0       0.0        5
# ...         ...       ...       ...       ...       ...       ...      ...
# 14995         1         1         1     1.000       1.0       1.0        5
# 14996         1         1         1     1.000       1.0       1.0        5
# 14997         1         1         1     1.000       1.0       1.0        3
# 14998         1         1         1     1.000       1.0       1.0        5
# 14999         1         1         1     1.000       1.0       1.0        5
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Columns: 507 entries, Theta_a1 to P2 Vector Cost
# dtypes: bool(1), float64(499), int64(7)
# memory usage: 57.9 MB
